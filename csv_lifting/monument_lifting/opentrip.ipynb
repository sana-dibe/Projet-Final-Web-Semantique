# %%
import requests
import json
import sys
import pandas as pd


apiKey="5ae2e3f221c38a28845f05b630c70950afc64c25ab9feb605eaae520"

# %%
place= input("input place");

place
# Out:
# input placeMilan
# 'Milan'

# %%
endpoint = "https://api.opentripmap.com/0.1/en/places/geoname?name=" + place + "&apikey=" + apiKey;
response = requests.get(endpoint)
print(response)

if (response.status_code == 200):

    content = response.text

    json_dict = json.loads(content)

    print(json_dict)

else:
    print("error")
# Out:
# <Response [200]>
# {'name': 'Milan', 'country': 'IT', 'lat': 45.46427, 'lon': 9.18951, 'population': 1236837, 'timezone': 'Europe/Rome', 'status': 'OK'}

# %%
lat = str(json_dict['lat'])
lon = str(json_dict['lon'])

# %%
url="https://api.opentripmap.com/0.1/en/places/radius?radius=1000&lon=" + lon + "&lat=" + lat + "&kinds=historic&limit=100&&apikey=5ae2e3f221c38a28845f05b630c70950afc64c25ab9feb605eaae520"
# &rate=3h
response1 = requests.get(url)
print(response1)
# Out:
# <Response [200]>

# %%
if (response1.status_code == 200):

    content1 = response1.text

    print(content1)

    json_dict1 = json.loads(content1)

    print(json_dict1)

else:
    print("error")
# Out:
# {"type":"FeatureCollection","features":[{"type":"Feature","id":"11247407","geometry":{"type":"Point","coordinates":[9.1892586,45.4641991]},"properties":{"xid":"W290222578","name":"Monumento a Vittorio Emanuele II","dist":21.2202974,"rate":3,"osm":"way/290222578","wikidata":"Q3862632","kinds":"historic,monuments_and_memorials,urban_environment,cultural,interesting_places,sculptures,monuments"}},{"type":"Feature","id":"15541309","geometry":{"type":"Point","coordinates":[9.1885786,45.464901]},"properties":{"xid":"Q56642054","name":"targa a Giovanni Ardizzone","dist":101.14397377,"rate":1,"wikidata":"Q56642054","kinds":"historic,monuments_and_memorials,burial_places,interesting_places,other_burial_places,monuments"}},{"type":"Feature","id":"11636466","geometry":{"type":"Point","coordinates":[9.1907482,45.4647026]},"properties":{"xid":"N4141759289","name":"Battistero di San Giovanni alle Fonti","dist":108.16204638,"rate":7,"osm":"node/4141759289","wikidata":"Q3636814","kinds":"religion,hi
# ...

# %%
data_init= pd.DataFrame(columns=['xid', 'name', 'lon', 'lat'])

for feature in json_dict1['features']:
  name=feature['properties']['name']
  xid = feature['properties']['xid']
  lon=feature['geometry']['coordinates'][0]
  lat=feature['geometry']['coordinates'][1]

  data_init.loc[len(data_init.index)] =[xid, name, lon, lat]

data_init
# Out:
#             xid                                               name       lon  \
# 0    W290222578                   Monumento a Vittorio Emanuele II  9.189259
# 1     Q56642054                         targa a Giovanni Ardizzone  9.188579
# 2   N4141759289              Battistero di San Giovanni alle Fonti  9.190748
# 3    Q103182978                 Milan (Samian Ware Discovery Site)  9.188140
# 4     Q60838459                                Statua di Martino V  9.191389
# 5     Q56642059                                     Broletto Nuovo  9.187810
# 6   N2075188888                           Milano per la Resistenza  9.187809
# 7     Q56642072                                 Via Tommaso Grossi  9.188909
# 8     Q56642075                            targa a Giuseppe Parini  9.187420
# 9   N2487295349                                          Madonnina  9.191892
# 10  N1295261412                                     Carlo Cattaneo  9.188415
# ...

# %%
from genericpath import exists
import pandas as pd

data= pd.DataFrame(columns=['xid', 'name', 'city', 'wiki_link','wikipedia_extracts'])

for value in data_init['xid']:
  url = "https://api.opentripmap.com/0.1/en/places/xid/" + value + "?apikey=5ae2e3f221c38a28845f05b630c70950afc64c25ab9feb605eaae520"
  response = requests.get(url)
  if (response1.status_code == 200):
    xid = 'null'
    name = 'null'
    city = 'null'
    link = 'null'
    extract = 'null'
    content = response.text

    json_dict = json.loads(content)
    print(json_dict)
    xid = json_dict['xid']
    name = json_dict['name']
    if 'city' in json_dict['address'].keys():
      city = json_dict['address']['city']
    else:
      json_dict['address']['state']
    if 'wikipedia' in json_dict.keys() :
      link = json_dict['wikipedia']
    if 'wikipedia_extracts' in json_dict.keys() :
      extract = json_dict['wikipedia_extracts']
    info = [xid, name, city, link,extract]
    data.loc[len(data.index)] =info
    # print(data)


  else:
    print("error")
# Out:
# {'xid': 'W290222578', 'name': 'Monumento a Vittorio Emanuele II', 'address': {'city': 'Milano', 'state': 'LOM', 'county': 'MI', 'suburb': 'Municipio 1', 'country': 'Italia', 'postcode': '20122', 'address29': 'Piazza del Duomo', 'pedestrian': 'Via Palazzo Reale', 'country_code': 'it', 'neighbourhood': 'Duomo'}, 'rate': '3', 'osm': 'way/290222578', 'bbox': {'lon_min': 9.189147, 'lon_max': 9.189371, 'lat_min': 45.464121, 'lat_max': 45.464274}, 'wikidata': 'Q3862632', 'kinds': 'historic,monuments_and_memorials,urban_environment,cultural,interesting_places,sculptures,monuments', 'sources': {'geometry': 'osm', 'attributes': ['osm', 'wikidata']}, 'otm': 'https://opentripmap.com/en/card/W290222578', 'wikipedia': 'https://it.wikipedia.org/wiki/Monumento%20a%20Vittorio%20Emanuele%20II%20%28Milano%29', 'image': 'https://commons.wikimedia.org/wiki/File:GiorcesMilanoVEII.JPG', 'preview': {'source': 'https://upload.wikimedia.org/wikipedia/commons/thumb/4/48/GiorcesMilanoVEII.JPG/400px-GiorcesMilan
# ...

# %%
pd.set_option('display.max_rows', None)

data['rating'] = 0

data['google_id'] = 'null'

# %%
import requests
google_APIKey="AIzaSyAiMl58fgl9CsdwHAP9FD6nmFlBYbLFfOs"

for name in data['name']:
  index = data.loc[data['name']==name,'rating']

  new_name=name.replace(' ','%20')
  url = "https://maps.googleapis.com/maps/api/place/findplacefromtext/json?input=" + name + "&inputtype=textquery&fields=formatted_address%2Cname%2Crating%2Cplace_id%2Cgeometry&key=AIzaSyAiMl58fgl9CsdwHAP9FD6nmFlBYbLFfOs"

  payload={}
  headers = {}

  response = requests.request("GET", url, headers=headers, data=payload)
  if (response1.status_code == 200):
    content = response.text
    # print(content)
    json_dict = json.loads(content)
    if json_dict['candidates']:
      data.loc[data['name']==name,'google_id'] = json_dict['candidates'][0]['place_id']
      if 'rating' in json_dict['candidates'][0].keys():
        data.loc[data['name']==name,'rating'] = json_dict['candidates'][0]['rating']

# %%
data
# Out:
#             xid                                               name    city  \
# 0    W290222578                   Monumento a Vittorio Emanuele II  Milano
# 1     Q56642054                         targa a Giovanni Ardizzone  Milano
# 2   N4141759289              Battistero di San Giovanni alle Fonti  Milano
# 3    Q103182978                 Milan (Samian Ware Discovery Site)  Milano
# 4     Q60838459                                Statua di Martino V  Milano
# 5     Q56642059                                     Broletto Nuovo  Milano
# 6   N2075188888                           Milano per la Resistenza  Milano
# 7     Q56642072                                 Via Tommaso Grossi  Milano
# 8     Q56642075                            targa a Giuseppe Parini  Milano
# 9   N2487295349                                          Madonnina  Milano
# 10  N1295261412                                     Carlo Cattaneo  Milano
# ...

# %%
# data.loc[:, 'opening_hours'] = 0

import requests

url = "https://maps.googleapis.com/maps/api/place/details/json?place_id=ChIJN1t_tDeuEmsRUsoyG83frY4&fields=name%2Crating%2Copening_hours&key=AIzaSyAiMl58fgl9CsdwHAP9FD6nmFlBYbLFfOs"

payload={}
headers = {}

response = requests.request("GET", url, headers=headers, data=payload)

json_dict = json.loads(response.text)

json_dict['result']['opening_hours']['weekday_text'][0]
# Out:
# 'Monday: 9:00\u202fAM\u2009–\u20095:00\u202fPM'

# %%
dict='null'
data.loc[:, 'opening_hours'] = dict
data
# Out:
#             xid                                               name    city  \
# 0    W290222578                   Monumento a Vittorio Emanuele II  Milano
# 1     Q56642054                         targa a Giovanni Ardizzone  Milano
# 2   N4141759289              Battistero di San Giovanni alle Fonti  Milano
# 3    Q103182978                 Milan (Samian Ware Discovery Site)  Milano
# 4     Q60838459                                Statua di Martino V  Milano
# 5     Q56642059                                     Broletto Nuovo  Milano
# 6   N2075188888                           Milano per la Resistenza  Milano
# 7     Q56642072                                 Via Tommaso Grossi  Milano
# 8     Q56642075                            targa a Giuseppe Parini  Milano
# 9   N2487295349                                          Madonnina  Milano
# 10  N1295261412                                     Carlo Cattaneo  Milano
# ...

# %%
for id in data['google_id']:
  url = "https://maps.googleapis.com/maps/api/place/details/json?place_id="+id+"&fields=name%2Crating%2Copening_hours&key=AIzaSyAiMl58fgl9CsdwHAP9FD6nmFlBYbLFfOs"

  payload={}
  headers = {}

  response = requests.request("GET", url, headers=headers, data=payload)

  if (response1.status_code == 200):
      content = response.text
      # print(content)
      json_dict = json.loads(content)
      # print(json_dict)

  if 'result' in json_dict.keys():
    if 'opening_hours' in json_dict['result'].keys():
      if 'weekday_text' in json_dict['result']['opening_hours'].keys():   
        dict_tmp=str(json_dict['result']['opening_hours']['weekday_text'])
        # print(dict_tmp)
        data.loc[data['google_id']==id,'opening_hours'] = dict_tmp
        # print(data['opening_hours'])

# %%
data= data.drop(data[data['opening_hours']=='null'].index)
data= data.drop(data[data['wiki_link']=='null'].index)
data= data.drop(data[data['wikipedia_extracts']=='null'].index)

data
# Out:
#             xid                              name    city  \
# 0    W290222578  Monumento a Vittorio Emanuele II  Milano
# 9   N2487295349                         Madonnina  Milano
# 10  N1295261412                    Carlo Cattaneo  Milano
# 11  N3310014533          Monumento al Carabiniere  Milano
# 15   W587569037      Statua di Alessandro Manzoni  Milano
# 19    Q51488957                   Porta Orientale  Milano
# 20  N1277284761       Statua di Leonardo da Vinci  Milano
# 23    Q57312417        Monument to Giulio Ricordi  Milano
# 25  N4209403195                       Foro Romano  Milano
# 26     Q4023993               Zecca di Mediolanum  Milano
# 29   N438108545            Fontana del Piermarini  Milano
# 31      Q729978                        Mediolanum  Milano
# 32   N611066173      Monumento a Giuseppe Missori  Milano
# 37  N4951005935          Statua a Cesare Beccaria  Milano
# 40    Q51488513                      Porta Romana  Milano
# ...

# %%
data.to_csv('Result13.csv')

# %%
files.download('/content/Result13.csv')

# %%
from google.colab import files

df = pd.read_csv('/content/drive/MyDrive/monuments.csv',encoding= 'unicode_escape')

df
# Out:
#              xid                                               name  \
# 0       R9396191           M¨¦morial des Martyrs de la D¨¦portation
# 1     N910390736                                       Conciergerie
# 2      W40579862                              Fontaine Saint-Michel
# 3     W311085062                              Fontaine Saint-Michel
# 4    N2667068593                                Fontaine du Palmier
# 5     W124052479                              M¨¦morial de la Shoah
# 6    N8784458609                                  maison d'Ourscamp
# 7     W791935186                                          Panth¨¦on
# 8      W55541122                                      H?tel de Sens
# 9    N3611368951                       Enceinte de Philippe-Auguste
# 10   N3740258948                                          Panth¨¦on
# 11     W52469222                             Fontaine des Innocents
# 12     W16407465                                          Panth¨¦on
# ...
